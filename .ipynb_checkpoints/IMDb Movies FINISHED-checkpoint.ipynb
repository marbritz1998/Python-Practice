# %% [markdown]
# **COMPLETED**

# %% [markdown]
# Problem Set can be found here: https://www.w3resource.com/python-exercises/pandas/movies/index.php

# %%
#importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %% [markdown]
# **Reading in Data**

# %%
movies = pd.read_csv('movies_metadata_copy1.csv', header = 0, encoding='latin-1')

# %%
movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# Thoughts:
#
# Initially, there was an error with pd.read_csv() where there was 25 lines and it expected 24 on line 31. So I opened up Excel, went to line 31 and saw an extra value and deleted it.
#
# Then when another error came up with utf encoding, so I looked at stack exchange and one of the solutions was setting the encoding to 'latin-1', so I changed the encoding to that and it works now. I honestly have no clue what this is doing or if it is reading in all the data.

# %% [markdown]
# **Problem 1)** Write a Python Pandas program to get the columns of the DataFrame (movies_metadata.csv file)

# %%
columns = list(movies.columns)
columns
# Out:
# ['adult',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'video',
#  'vote_average',
#  'vote_count']

# %% [markdown]
# **Sample Solution 1)**

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('movies_metadata.csv')
print("Columns of the DataFrame:")
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-15-07d5f6f54808> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 df = pd.read_csv('movies_metadata.csv')
#       4 print("Columns of the DataFrame:")
#       5 print(df.columns)
#
# ...

# %% [markdown]
# Again, the sample solution only uses pd.read_csv(), this will not work, as I have described above!

# %% [markdown]
# **Problem 2)** Write a Pandas program to get the information of the DataFrame (movies_metadata.csv file)including data types and memory usage.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  50 non-null     bool
#  1   belongs_to_collection  10 non-null     object
#  2   budget                 50 non-null     int64
#  3   genres                 50 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     50 non-null     int64
#  6   imdb_id                50 non-null     object
#  7   original_language      50 non-null     object
#  8   original_title         50 non-null     object
#  9   overview               49 non-null     object
#  10  popularity             50 non-null     object
#  11  poster_path            50 non-null     object
#  12  production_companies   50 non-null     object
#  13  production_countries   50 non-null     object
# ...

# %% [markdown]
# **Problem 3)** Write a Pandas program to get the details of the third movie of the DataFrame (movies_metadata.csv file)

# %%
movies.iloc[2]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# **Problem 4)** Write a Pandas program to count the number of rows and columns of the DataFrame (movies_metadata.csv file)

# %%
movies.shape
# Out:
# (50, 24)

# %%
print('# of rows')
print(movies.shape[0])
print('# of columns')
print(movies.shape[1])
# Out:
# # of rows
# 50
# # of columns
# 24

# %% [markdown]
# **Problem 5)** Write a Pandas program to get the details of the columns title and genres of the DataFrame.

# %%
movies.loc[:,['title','genres']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   50 non-null     object
#  1   genres  50 non-null     object
# dtypes: object(2)
# memory usage: 928.0+ bytes

# %%
movies.loc[:,['title','genres']].describe()
# Out:
#                                 title  \
# count                              50
# unique                             50
# top     How To Make An American Quilt
# freq                                1
#
#                                                    genres
# count                                                  50
# unique                                                 39
# top     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# freq                                                    6

# %% [markdown]
# **Problem 6)** Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'.

# %%
movies[movies['title'] == 'Grumpier Old Men']
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview  ... release_date  \
# 2  A family wedding reignites the ancient feud be...  ...   12/22/1995
#
#   revenue runtime                          spoken_languages    status  \
# 2       0     101  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  FALSE
#
#   vote_average vote_count
# 2          6.5       92.0
#
# [1 rows x 24 columns]

# %% [markdown]
# **Problem 7)** Write a Pandas program to get the details of  fifth movie of the DataFrame.

# %%
movies.loc[4]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 96871, 'name': 'Father of the Bride Col...
# budget                                                                   0
# genres                                      [{'id': 35, 'name': 'Comedy'}]
# homepage                                                               NaN
# id                                                                   11862
# imdb_id                                                          tt0113041
# original_language                                                       en
# original_title                                 Father of the Bride Part II
# overview                 Just when George Banks has recovered from his ...
# popularity                                                        8.387519
# poster_path                               /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...

# %% [markdown]
# **Problem 8)** Write a Pandas program to create a smaller DataFrame with a subset of all features.

# %%
movies_small = movies.loc[0:10]
movies_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  11 non-null     bool
#  1   belongs_to_collection  4 non-null      object
#  2   budget                 11 non-null     int64
#  3   genres                 11 non-null     object
#  4   homepage               2 non-null      object
#  5   id                     11 non-null     int64
#  6   imdb_id                11 non-null     object
#  7   original_language      11 non-null     object
#  8   original_title         11 non-null     object
#  9   overview               11 non-null     object
#  10  popularity             11 non-null     object
#  11  poster_path            11 non-null     object
#  12  production_companies   11 non-null     object
#  13  production_countries   11 non-null     object
# ...

# %% [markdown]
# **Problem 9)** Write a Pandas program to display the first 10 rows of the DataFrame.

# %%
movies.loc[0:9]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %% [markdown]
# **Problem 10)** Write a Pandas program to sort the DataFrame based on release_date

# %%
movies.sort_values('release_date')
# Out:
#     adult                              belongs_to_collection    budget  \
# 36  False                                                NaN         0
# 26  False                                                NaN  12000000
# 20  False  {'id': 91698, 'name': 'Chili Palmer Collection...  30250000
# 24  False                                                NaN   3600000
# 23  False                                                NaN         0
# 21  False                                                NaN         0
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 45  False                                                NaN  10000000
# 41  False                                                NaN  10000000
# 22  False                                                NaN  50000000
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# ...

# %% [markdown]
# **Problem 11)** Write a Pandas program to access those movies, released after 1995-01-01

# %%
movies[movies['release_date'] > '1995-01-01']
# Out:
#     adult                              belongs_to_collection    budget  \
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 27  False                                                NaN         0
# 28  False                                                NaN  18000000
# 29  False                                                NaN         0
# 30  False                                                NaN         0
# 32  False                                                NaN         0
# 33  False  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
# 38  False                                                NaN  12000000
# 43  False  {'id': 9818, 'name': 'Mortal Kombat Collection...  18000000
# 44  False                                                NaN  20000000
# 46  False                                                NaN  33000000
# 47  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# ...

# %% [markdown]
# **Problem 12)** Write a Pandas program to sort movies on runtime in descending order

# %%
movies.sort_values('runtime', ascending = False)
# Out:
#     adult                              belongs_to_collection    budget  \
# 13  False                                                NaN  44000000
# 15  False                                                NaN  52000000
# 5   False                                                NaN  60000000
# 16  False                                                NaN  16500000
# 22  False                                                NaN  50000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 31  False                                                NaN  29500000
# 46  False                                                NaN  33000000
# 3   False                                                NaN  16000000
# 6   False                                                NaN  58000000
# 21  False                                                NaN         0
# 25  False                                                NaN         0
# ...

# %% [markdown]
# **Problem 13)** Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million

# %%
movies[(movies['revenue'] > '2000000')& (movies['budget'] < 1000000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 4 to 39
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  3 non-null      bool
#  1   belongs_to_collection  1 non-null      object
#  2   budget                 3 non-null      int64
#  3   genres                 3 non-null      object
#  4   homepage               0 non-null      object
#  5   id                     3 non-null      int64
#  6   imdb_id                3 non-null      object
#  7   original_language      3 non-null      object
#  8   original_title         3 non-null      object
#  9   overview               3 non-null      object
#  10  popularity             3 non-null      object
#  11  poster_path            3 non-null      object
#  12  production_companies   3 non-null      object
#  13  production_countries   3 non-null      object
# ...

# %% [markdown]
# **Problem 14)** Write a Pandas program to get the longest runtime and shortest runtime

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
print('Longest runtime')
print(movies['runtime'].max())
print('shortest runtime')
print(movies['runtime'].min())
# Out:
# Longest runtime
# 192
# shortest runtime
# 0

# %%
movies[movies['runtime'] == movies['runtime'].min()]
# Out:
#     adult belongs_to_collection  budget  \
# 29  False                   NaN       0
#
#                                                genres homepage     id  \
# 29  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...      NaN  37557
#
#       imdb_id original_language original_title overview  ...  \
# 29  tt0115012                zh            ???    ?????  ...
#
#                                          release_date    revenue runtime  \
# 29  [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...  4/30/1995       0
#
#    spoken_languages                                status   tagline  \
# 29              108  [{'iso_639_1': 'zh', 'name': '???'}]  Released
#
#                                                 title           video  \
# 29  In 1930's Shanghai violence was not the proble...  Shanghai Triad
#
#    vote_average vote_count
# 29        FALSE        6.5
#
# [1 rows x 24 columns]

# %%
movies.drop(index=29, inplace = True)
movies['runtime'].min()
# Out:
# 50

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Problem 15) Write a Pandas program to calculate the number of votes garnered by the 70% movie

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#this question confuses me...

# %%
movies['vote_count'].quantile(0.7)
# Out:
# 411.39999999999986

# %% [markdown]
# **Problem 16)** Write a Pandas program to display the movies (title, runtime) longer than 30 minutes and shorter than 360 minutes

# %%
movies[(movies['runtime'] > 30) & (movies['runtime'] < 360)].loc[:,['title', 'runtime']]
# Out:
#                              title  runtime
# 0                        Toy Story       81
# 1                          Jumanji      104
# 2                 Grumpier Old Men      101
# 3                Waiting to Exhale      127
# 4      Father of the Bride Part II      106
# 5                             Heat      170
# 6                          Sabrina      127
# 7                     Tom and Huck       97
# 8                     Sudden Death      106
# 9                        GoldenEye      130
# 10          The American President      106
# 11     Dracula: Dead and Loving It       88
# 12                           Balto       78
# 13                           Nixon      192
# 14                Cutthroat Island      119
# 15                          Casino      178
# 16           Sense and Sensibility      136
# 17                      Four Rooms       98
# 18  Ace Ventura: When Nature Calls       90
# 19                     Money Train      103
# ...

# %% [markdown]
# **Problem 17)** Write a Pandas program to display the movies (title, number of votes) that received specified number of votes.

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#I am not sure what this question is asking...
