# %% [markdown]
# Currently on Problem 11

# %% [markdown]
# Problems can be found here: https://www.w3resource.com/python-exercises/pandas/missing-values/index.php

# %%
import pandas as pd
import numpy as np

# %%
#Loading data
data = pd.read_csv('handling missing values example.csv', sep='\s+')
data
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %% [markdown]
# **Problem 1)** Write a Pandas program to detect missing values of a given DataFrame. Display True or False

# %%
data.isnull()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# Sample Solution 1)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nMissing values of the said dataframe:")
print(df.isna())
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Missing values of the said dataframe:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# ...

# %% [markdown]
# Thoughts: Interesting that the sample solution uses df.isna() where as I used df.isnull(), which both produce the exact same result. I found this Stack Exchange Post which compares .isna() to .isnull()
#
# https://datascience.stackexchange.com/questions/37878/difference-between-isna-and-isnull-in-pandas
#
# Conclusion: They behave exactly the same!

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Problem 2) Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value

# %%
for column in data.columns:
    if data[column].isna().any() == True:
        print('The ' + str(column) + ' column'+ ' contains atleast one missing value')
# Out:
# The ord_no column contains atleast one missing value
# The ord_date column contains atleast one missing value
# The salesman_id column contains atleast one missing value

# %% [markdown]
# Sample Solution 2)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nIdentify the columns which have at least one missing value:")
print(df.isna().any())
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Identify the columns which have at least one missing value:
# ord_no          True
# purch_amt      False
# ord_date        True
# ...

# %% [markdown]
# Thoughts: So to detect columns that have missing values, all I had to do was use df.isna().any()

# %%
data.isna().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Problem 3) Write a Pandas program to count the number of missing values in each column of a given DataFrame.

# %%
data
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
data.isna().apply(pd.Series.value_counts)
# Out:
#        ord_no  purch_amt  ord_date  customer_id  salesman_id
# False       8       12.0        11         12.0            9
# True        4        NaN         1          NaN            3

# %% [markdown]
# Thoughts: This was a pretty challenging problem and I sort of solved it. Indeed the above does give the number of missing values per column, though you have to understand the code to understand the outcome, like the fact that True corresponds to missing values and that NaN means there are 0 missing values for the given column. also im using pandas version 1.0.1. If I had version 1.1.1 on onwards, I could have just used value_counts() on the dataframe directly.

# %% [markdown]
# Sample Solution 3)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nNumber of missing values of the said dataframe:")
print(df.isna().sum())
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Number of missing values of the said dataframe:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# ...

# %% [markdown]
# Thoughts: all they did was use df.isna().sum()   Pretty clever, since for Bools, False has a value of 0 and True has a value of 1

# %% [markdown]
# **Problem 4)** Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.

# %%
#loading data
data = pd.read_csv('handle missing data example 4.txt', sep = '\s+')
data
# Out:
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5           ?        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001           ?
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6      --      5760  2012-09-10        3001        5001
# 7   70010         ?  2012-10-10        3004           ?
# 8   70003     12.43  2012-10-10          --        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001          --

# %%
#so '?' and '--' need to be replaced with NaN
data_replaced = data.replace(['?', '--'],[np.nan,np.nan])
data_replaced
# Out:
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5         NaN        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001         NaN
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6     NaN      5760  2012-09-10        3001        5001
# 7   70010       NaN  2012-10-10        3004         NaN
# 8   70003     12.43  2012-10-10         NaN        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001         NaN

# %% [markdown]
# Sample Solution 4)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,"--",70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,"?",12.43,2480.4,250.45, 3045.6],
'ord_date': ['?','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,"--",3002,3001,3001],
'salesman_id':[5002,5003,"?",5001,np.nan,5002,5001,"?",5003,5002,5003,"--"]})
print("Original Orders DataFrame:")
print(df)
print("\nReplace the missing values with NaN:")
result = df.replace({"?": np.nan, "--": np.nan})
print(result)
# Out:
# Original Orders DataFrame:
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5           ?        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001           ?
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6      --      5760  2012-09-10        3001        5001
# 7   70010         ?  2012-10-10        3004           ?
# 8   70003     12.43  2012-10-10          --        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001          --
#
# Replace the missing values with NaN:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50         NaN       3002.0       5002.0
# ...

# %% [markdown]
# Thoughts: My solution and the sample solution result in the exact same outcome, they just chose to use a dictionary instead of lists

# %% [markdown]
# **Problem 5)** Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.

# %%
#Loading data
data = pd.read_csv('handling missing values example.csv', sep='\s+')
data.head(5)
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 1      NaN     270.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26         NaN         3001       5001.0
# 3  70004.0     110.50  2012-08-17         3003          NaN
# 4      NaN     948.50  2012-09-10         3002       5002.0

# %%
data_na_dropped = data.dropna()
data_na_dropped
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %% [markdown]
# Sample Solution 5)

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

print("Original Orders DataFrame:")
print(df)
print("\nDrop the rows where at least one element is missing:")
result = df.dropna()
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Drop the rows where at least one element is missing:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# ...

# %% [markdown]
# **Problem 6)** Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.

# %%
data.head()
data.dropna(axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %% [markdown]
# **Problem 7)** Write a Pandas program to drop the rows where all elements are missing in a given DataFrame

# %%
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[np.nan,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': [np.nan,'2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[np.nan,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[np.nan,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

# %%
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0       NaN        NaN         NaN          NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0       5001.0
# 3   70004.0     110.50  2012-08-17       3003.0          NaN
# 4       NaN     948.50  2012-09-10       3002.0       5002.0
# 5   70005.0    2400.60  2012-07-27       3001.0       5001.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0    1983.43  2012-10-10       3004.0          NaN
# 8   70003.0    2480.40  2012-10-10       3003.0       5003.0
# 9   70012.0     250.45  2012-06-27       3002.0       5002.0
# 10      NaN      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN

# %%
df.dropna(how='all')
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 1       NaN     270.65  2012-09-10       3001.0       5003.0
# 2   70002.0      65.26         NaN       3001.0       5001.0
# 3   70004.0     110.50  2012-08-17       3003.0          NaN
# 4       NaN     948.50  2012-09-10       3002.0       5002.0
# 5   70005.0    2400.60  2012-07-27       3001.0       5001.0
# 6       NaN    5760.00  2012-09-10       3001.0       5001.0
# 7   70010.0    1983.43  2012-10-10       3004.0          NaN
# 8   70003.0    2480.40  2012-10-10       3003.0       5003.0
# 9   70012.0     250.45  2012-06-27       3002.0       5002.0
# 10      NaN      75.29  2012-08-17       3001.0       5003.0
# 11  70013.0    3045.60  2012-04-25       3001.0          NaN

# %% [markdown]
# **Problem 8)** Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.

# %%
#loading data
data = pd.read_csv('missing data ex 8.txt', sep = '\s+')
data
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN

# %%
for index in data.index:
    if data.loc[index,:].isna().sum() <2:
        data.drop(index = index, inplace = True)
data
# Out:
#     ord_no  purch_amt ord_date  customer_id
# 0      NaN        NaN      NaN          NaN
# 3      NaN        NaN      NaN          NaN
# 11     NaN        NaN      NaN          NaN

# %% [markdown]
# Thoughts: I was able to get the solution, but I had to resort to a for loop, wonder what the sample solution will use

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nKeep the rows with at least 2 NaN values of the said DataFrame:")
result = df.dropna(thresh=2)
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
# Keep the rows with at least 2 NaN values of the said DataFrame:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# ...

# %% [markdown]
# Thoughts: So the sample solution is **WRONG** , the parameter 'thresh' in the .dropna() function refers to the presence of non-NA values, not NA values.  You can see this in many of the rows, where there is only 1 NaN value, yet the question requires there to be **ATLEAST** 2 NaN values

# %% [markdown]
# **Problem 9)** Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.

# %%
#loading data
data = pd.read_csv('missing data ex9.txt', sep = '\s+')
data
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN

# %%
data.dropna(subset=['ord_no'])
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 2  70002.0      65.26         NaN       3001.0
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %%
data.dropna(subset=['ord_no', 'ord_date'])
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# **Problem 10)** Write a Pandas program to keep the valid entries of a given DataFrame.

# %%
data
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN

# %% [markdown]
# Thoughts: I am not sure what this question is wanting me to do. The dataframe already has all the valid entries in it. If it wants me to replace the NaN with 0 or some shit, that would make sense, but 'keep the valid entries', I already have all the valid entries pal. Will look at sample solution to gain any insight

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nKeep the said DataFrame with valid entries:")
result = df.dropna(inplace=False)
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
# Keep the said DataFrame with valid entries:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %% [markdown]
# Thoughts: Okay, so all they did was remove all the NaN values, thus leaving entries that are not 'NaN'. Again, the question was not clear.

# %% [markdown]
# **Problem 11.)** Write a Pandas program to calculate the total number of missing values in a DataFrame

# %%
#Loading data
data = pd.read_csv('missing_data11.txt',header = 0, sep='\s+')
data.head()
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 0      NaN        NaN         NaN          NaN
# 1      NaN     270.65  2012-09-10       3001.0
# 2  70002.0      65.26         NaN       3001.0
# 3      NaN        NaN         NaN          NaN
# 4      NaN     948.50  2012-09-10       3002.0

# %%
print('Missing data in columns:')
print(data.isna().sum())
print('\nTotal Number of missing values:')
print(data.isna().sum().sum())
# Out:
# Missing data in columns:
# ord_no         7
# purch_amt      3
# ord_date       4
# customer_id    3
# dtype: int64
#
# Total Number of missing values:
# 17

# %% [markdown]
# **Sample Solution 11.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nTotal number of missing values of the said DataFrame:")
result = df.isna().sum().sum()
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
# Total number of missing values of the said DataFrame:
# 17

# %% [markdown]
# **Problem 12.)** Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame

# %%
#loading data
data = pd.read_csv('missing_data11.txt',header = 0, sep='\s+')
data.head()
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 0      NaN        NaN         NaN          NaN
# 1      NaN     270.65  2012-09-10       3001.0
# 2  70002.0      65.26         NaN       3001.0
# 3      NaN        NaN         NaN          NaN
# 4      NaN     948.50  2012-09-10       3002.0

# %%
#will use nested dictionaries
new_data = data.replace({'ord_no': {np.nan:'00000'}, 'ord_date': {np.nan:'0000-00-00'}})
new_data.head()
# Out:
#   ord_no  purch_amt    ord_date  customer_id
# 0  00000        NaN  0000-00-00          NaN
# 1  00000     270.65  2012-09-10       3001.0
# 2  70002      65.26  0000-00-00       3001.0
# 3  00000        NaN  0000-00-00          NaN
# 4  00000     948.50  2012-09-10       3002.0

# %% [markdown]
# **Sample Solution 12.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nReplace NaNs with a single constant value:")
result = df['ord_no'].fillna(0, inplace=False)
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Replace NaNs with a single constant value:
# 0     70001.0
# 1         0.0
# 2     70002.0
# 3     70004.0
# 4         0.0
# 5     70005.0
# ...

# %% [markdown]
# **Problem 13.)** Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %%
data.fillna(method='ffill', inplace = True) #note, since it wants me to fill nan with the value in the row ABOVE
# i.e. the previous row, I will need to use forward fill, which will fill the nan with the value of the row 
# above it, assuming a value exists
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1  70001.0     150.50     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26     20.65  2012-09-10         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4  70004.0     948.50     98.50  2012-09-10         3002       5002.0

# %% [markdown]
# **Sample Solution 13.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("\nReplacing NaNs with the value from the previous row (purch_amt):")
df['purch_amt'].fillna(method='pad', inplace=True)
print(df)
print("\nReplacing NaNs with the value from the next row (sale_amt):")
df['sale_amt'].fillna(method='bfill', inplace=True)
print(df)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# ...

# %% [markdown]
# **Problem 14.)** Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame.

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %%
data.fillna(value={'ord_no': data['ord_no'].mean(), 'purch_amt' : data['purch_amt'].mean(),
                   'sale_amt': data['sale_amt'].mean(),
                  'customer_id': data['customer_id'].mean(), 'salesman_id': data['salesman_id'].mean()})
# Out:
#       ord_no    purch_amt   sale_amt    ord_date  customer_id  salesman_id
# 0   70001.00   150.500000  10.500000  2012-10-05         3002       5002.0
# 1   70006.25  1376.614444  20.650000  2012-09-10         3001       5003.0
# 2   70002.00    65.260000  39.324444         NaN         3001       5001.0
# 3   70004.00   110.500000  11.500000  2012-08-17         3003       5002.0
# 4   70006.25   948.500000  98.500000  2012-09-10         3002       5002.0
# 5   70005.00  1376.614444  39.324444  2012-07-27         3001       5001.0
# 6   70006.25  5760.000000  57.000000  2012-09-10         3001       5001.0
# 7   70010.00  1983.430000  19.430000  2012-10-10         3004       5002.0
# 8   70003.00  1376.614444  39.324444  2012-10-10         3003       5003.0
# 9   70012.00   250.450000  25.450000  2012-06-27         3002       5002.0
# 10  70006.25    75.290000  75.290000  2012-08-17         3001       5003.0
# ...

# %% [markdown]
# **Sample solution 14.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df)
print("Using median in purch_amt to replace NaN:")
df['purch_amt'].fillna(df['purch_amt'].median(), inplace=True)
print(df)
print("Using mean to replace NaN:")
df['sale_amt'].fillna(int(df['sale_amt'].mean()), inplace=True)
print(df)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ...

# %% [markdown]
# **Problem 15.)** Write a Pandas program to interpolate the missing values using the Linear Interpolation method in a given DataFrame

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %% [markdown]
# data.interpolate(inplace = True)

# %%
data['ord_date'].interpolate(method = 'time', inplace = True)

# %%
data  #so the interpolation for the ord_date column didn't do anything, worth investigating
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50    10.500  2012-10-05         3002       5002.0
# 1   70001.5     107.88    20.650  2012-09-10         3001       5003.0
# 2   70002.0      65.26    16.075         NaN         3001       5001.0
# 3   70004.0     110.50    11.500  2012-08-17         3003       5001.5
# 4   70004.5     948.50    98.500  2012-09-10         3002       5002.0
# 5   70005.0    3354.25    77.750  2012-07-27         3001       5001.0
# 6   70007.5    5760.00    57.000  2012-09-10         3001       5001.0
# 7   70010.0    1983.43    19.430  2012-10-10         3004       5002.0
# 8   70003.0    1116.94    22.440  2012-10-10         3003       5003.0
# 9   70012.0     250.45    25.450  2012-06-27         3002       5002.0
# 10  70012.5      75.29    75.290  2012-08-17         3001       5003.0
# 11  70013.0    3045.60    35.600  2012-04-25         3001       5003.0

# %% [markdown]
# **Sample Solution 15.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df) 
print("\nInterpolate the missing values using the Linear Interpolation method (purch_amt):")
df['purch_amt'].interpolate(method='linear', direction = 'forward', inplace=True) 
print(df)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# ...

# %% [markdown]
# **Problem 16.)** Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %%
data['ord_no'].isna().sum()
# Out:
# 4

# %%
data.isna().sum()
# Out:
# ord_no         4
# purch_amt      3
# sale_amt       3
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# **Sample Solution 16.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df) 
print("\nMissing values in purch_amt column:")
result = df['purch_amt'].value_counts(dropna=False).loc[np.nan]
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# ...

# %% [markdown]
# **Problem 17.)** Write a Pandas program to count the missing values in a given DataFrame

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %%
print('Number of Missing Values is:')
data.isna().sum().sum()
# Out:
# Number of Missing Values is:
# 14

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Problem 18.) Write a Pandas program to find the Indexes of missing values in a given DataFrame

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %% [markdown]
# **Sample Solution 18.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df) 
print("\nMissing values in purch_amt column:")
result = df['purch_amt'].isnull().to_numpy().nonzero()
display(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# ...

# %% [markdown]
# **Problem 19.)** Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %%
data['customer_id'].mode()
# Out:
# 0    3001
# dtype: int64

# %%
data['customer_id'].value_counts().idxmax()
# Out:
# 3001

# %%
data['customer_id'].fillna(value = data['customer_id'].mode())
# Out:
# 0     3002
# 1     3001
# 2     3001
# 3     3003
# 4     3002
# 5     3001
# 6     3001
# 7     3004
# 8     3003
# 9     3002
# 10    3001
# 11    3001
# Name: customer_id, dtype: int64

# %%
data.fillna(value = {'customer_id': {np.nan : data['customer_id'].mode()}})
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %% [markdown]
# **Sample Solution 19.)**

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
print("Original Orders DataFrame:")
print(df) 
print("\nReplace the missing values with the most frequent values present in each column:")
result = df.fillna(df.mode().iloc[0])
print(result)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
#
# ...

# %% [markdown]
# Note that for the sample solution here, if the mode had multiple values, they chose the first value

# %% [markdown]
# **Problem 20.)** Write a Pandas program to create a hitmap for more information about the distribution of missing values in a given DataFrame

# %%
#loading data
data = pd.read_csv('missing_data13.txt', header = 0, sep = '\s+')
data.head()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1      NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26       NaN         NaN         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4      NaN     948.50     98.50  2012-09-10         3002       5002.0

# %% [markdown]
# **Sample Solution 20.)**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})
plt.figure(figsize=(16,10))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\Matthew\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# lol looks like the sample solution is depreciated...
