# %% [markdown]
# **COMPLETED**

# %% [markdown]
# Can Find problems here: https://www.w3resource.com/python-exercises/pandas/filter/index.php

# %%
import numpy as np
import pandas as pd

# %%
#Loading Data
world_alcohol = pd.read_csv('world_alcohol.csv')
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %% [markdown]
# **Problem 1)** Write a Pandas program to display the dimensions or shape of the World alcohol consumption dataset. Also extract the column names from the dataset.

# %%
print('Shape of World Alcohol Consumption Dataset')
print(world_alcohol.shape)

print('\nColumn Names')
print(world_alcohol.columns)
# Out:
# Shape of World Alcohol Consumption Dataset
# (100, 5)
#
# Column Names
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %% [markdown]
# Sample Solution 1)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print('\nShape of the dataframe: ',w_a_con.shape)
print('\nNumber of rows: ',w_a_con.shape[0])
print('\nNumber of column: ',w_a_con.shape[1])
print("\nExtract Column Names:")
print(w_a_con.columns)
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Shape of the dataframe:  (100, 5)
#
# Number of rows:  100
#
# Number of column:  5
#
# Extract Column Names:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %% [markdown]
# **Problem 2)** Write a Pandas program to select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.

# %%
#Loading Data
world_alcohol = pd.read_csv('world_alcohol.csv')
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
print(world_alcohol.iloc[0:3, 0:3])

print('\nor doing loc with specified columns')
print(world_alcohol.loc[0:3,['Country', 'Beverage Types']])
# Out:
#    Year       WHO region       Country
# 0  1986  Western Pacific      Viet Nam
# 1  1986         Americas       Uruguay
# 2  1985           Africa  Cte d'Ivoire
#
# or doing loc with specified columns
#         Country Beverage Types
# 0      Viet Nam           Wine
# 1       Uruguay          Other
# 2  Cte d'Ivoire           Wine
# 3      Colombia           Beer

# %% [markdown]
# Sample Solution 2)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nSelect first 2 rows:")
print(w_a_con.iloc[:2])
print("\nSelect first 2 columns:")
print(w_a_con.iloc[:,:2].head())
print("\nSelect 2 specific columns:")
print(w_a_con[['Display Value', 'Year']])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Select first 2 rows:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5
#
# Select first 2 columns:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas
# 2  1985           Africa
# 3  1986         Americas
# 4  1987         Americas
#
# Select 2 specific columns:
#     Display Value  Year
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Problem 3) Write a Pandas program to select random number of rows, fraction of random rows from World alcohol consumption dataset.

# %%
#Loading Data
#Loading Data
world_alcohol = pd.read_csv('world_alcohol.csv')
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
random_integer = np.random.randint(0,world_alcohol.index.max())
print(world_alcohol.iloc[:random_integer])
# Out:
#     Year             WHO region  \
# 0   1986        Western Pacific
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 6   1987                 Africa
# 7   1985                 Africa
# 8   1986               Americas
# 9   1984                 Africa
# 10  1987                 Africa
# 11  1989               Americas
# 12  1985        Western Pacific
# 13  1984  Eastern Mediterranean
# 14  1985        Western Pacific
# 15  1987                 Africa
# 16  1984               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 20  1986        South-East Asia
# 21  1989               Americas
# 22  1984                 Europe
# 23  1984                 Europe
# 24  1985                 Africa
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# ...

# %% [markdown]
# Sample Solution 3)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nSelect random number of rows:")
print(w_a_con.sample(5))
print("\nSelect fraction of randome rows:")
print(w_a_con.sample(frac=0.02))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Select random number of rows:
#     Year             WHO region      Country Beverage Types  Display Value
# 83  1986                 Europe      Ukraine          Other            NaN
# 13  1984  Eastern Mediterranean  Afghanistan          Other           0.00
# 65  1989  Eastern Mediterranean      Somalia           Beer           0.00
# 22  1984                 Europe      Romania        Spirits           2.67
# ...

# %% [markdown]
# Thoughts: The sample solution used a new method I haven't seen before, pd.sample()
# this method returns a certain number of entries, in which those entries are random subsections of the dataset. I had a different interpretation of the question. I chose a random subsection of the dataset completely, it wasn't constrained to a certain number of entries, the number of entries itself was random. This could be a useful method in some scenarios

# %% [markdown]
# **Problem 4)** Write a Pandas program to find and drop the missing values from World alcohol consumption dataset.

# %%
#Loading Data
world_alcohol = pd.read_csv('world_alcohol.csv')
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
print('full dataset shape')
print(world_alcohol.shape)

print('Removing rows that have missing values')
print(world_alcohol.dropna().shape)
# Out:
# full dataset shape
# (100, 5)
# Removing rows that have missing values
# (95, 5)

# %% [markdown]
# Sample Solution 4)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nMissing values:")
print(w_a_con.isnull())
print("\nDropping the missing values:")
print(w_a_con.dropna())
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Missing values:
#      Year  WHO region  Country  Beverage Types  Display Value
# 0   False       False    False           False          False
# 1   False       False    False           False          False
# 2   False       False    False           False          False
# 3   False       False    False           False          False
# 4   False       False    False           False          False
# ..    ...         ...      ...             ...            ...
# ...

# %%
#Wanting to print rows in world alcohol that have null values
print('rows with missing values')
world_alcohol_null = pd.DataFrame()
null_index = []
for index in world_alcohol.index:
    if world_alcohol.loc[index].isnull().any() == True:
        null_index.append(index)
print(world_alcohol[world_alcohol.index.isin(null_index)])
# Out:
# rows with missing values
#     Year WHO region     Country Beverage Types  Display Value
# 24  1985     Africa     Comoros          Other            NaN
# 29  1986     Europe       Italy          Other            NaN
# 44  1985     Europe   Lithuania          Other            NaN
# 83  1986     Europe     Ukraine          Other            NaN
# 93  1987     Africa  Madagascar          Other            NaN

# %% [markdown]
# Was just trying something above, glad I figured it out, albiet my first solution takes multiple lines and seems quite complicated for wanting to do such a simple task

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Problem 5) Write a Pandas program to remove the duplicates from 'WHO region' column of World alcohol consumption dataset.

# %%
#Loading Data
world_alcohol = pd.read_csv('world_alcohol.csv')
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
#says to remove duplicates, so I will keep the first instance of WHO region, and remove all other instances from there
world_alcohol_dp_rem = world_alcohol[world_alcohol.duplicated(subset = 'WHO region') == False]
print(world_alcohol_dp_rem.shape)
world_alcohol_dp_rem
# Out:
# (6, 5)
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# Sample Solution 5)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())

print("\nAfter removing the duplicates of WHO region column:")
w_a_con.drop_duplicates('WHO region')
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# After removing the duplicates of WHO region column:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# ...

# %% [markdown]
# Thoughts: The sample solution made use of a new method I haven't seen, pd.drop_duplicates()  . Though I got the same answer as them, the drop_duplicates method is simpler than the methodolgy I employed

# %% [markdown]
# **Problem 6)** Write a Pandas program to find out the alcohol consumption of a given year from the world alcohol consumption dataset

# %%
# loading data
world_alcohol = pd.read_csv('world_alcohol.csv')
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol_1986 = world_alcohol[world_alcohol['Year'] == 1986]
world_alcohol_1986.head()
# Out:
#     Year       WHO region              Country Beverage Types  Display Value
# 0   1986  Western Pacific             Viet Nam           Wine           0.00
# 1   1986         Americas              Uruguay          Other           0.50
# 3   1986         Americas             Colombia           Beer           4.27
# 8   1986         Americas  Antigua and Barbuda        Spirits           1.55
# 20  1986  South-East Asia              Myanmar           Wine           0.00

# %% [markdown]
# Sample Solution 6)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details in the year 1985:")
print(w_a_con[w_a_con['Year']==1985].head(10))
print("\nThe world alcohol consumption details in the year 1989:")
print(w_a_con[w_a_con['Year']==1989].head(10))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details in the year 1985:
#     Year       WHO region                                            Country  \
# 2   1985           Africa                                       Cte d'Ivoire
# 7   1985           Africa                                             Angola
# 12  1985  Western Pacific                   Lao People's Democratic Republic
# 14  1985  Western Pacific                                           Viet Nam
# ...

# %% [markdown]
# **Problem 7)** Write a Pandas program to find out the alcohol consumption details in the year '1987' or '1989' from the world alcohol consumption dataset

# %%
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa_1987 = world_alcohol[world_alcohol['Year'] == 1987]
wa_1987.describe(include=object)
# Out:
#        WHO region   Country Beverage Types
# count          21        21             21
# unique          5        20              4
# top        Africa  Viet Nam          Other
# freq            6         2              6

# %% [markdown]
# Sample Solution 7)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details where year is 1987 or 1989:")
print((w_a_con[(w_a_con['Year']==1987) | (w_a_con['Year']==1989)]).head(10))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details where year is 1987 or 1989:
#     Year       WHO region                Country Beverage Types  Display Value
# 4   1987         Americas  Saint Kitts and Nevis           Beer           1.98
# 5   1987         Americas              Guatemala          Other           0.00
# 6   1987           Africa              Mauritius           Wine           0.13
# 10  1987           Africa               Botswana           Wine           0.20
# ...

# %% [markdown]
# **Problem 8)** Write a Pandas program to find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset.

# %%
wa = world_alcohol
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa_america = wa[wa['WHO region'] == 'Americas']
wa_america.head()
# Out:
#    Year WHO region                Country Beverage Types  Display Value
# 1  1986   Americas                Uruguay          Other           0.50
# 3  1986   Americas               Colombia           Beer           4.27
# 4  1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 5  1987   Americas              Guatemala          Other           0.00
# 8  1986   Americas    Antigua and Barbuda        Spirits           1.55

# %% [markdown]
# Sample Solution 8)  The link for this solution doesn't exist anymore.

# %% [markdown]
# **Problem 9)** Write a Pandas program to find out the alcohol consumption details in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from the world alcohol consumption dataset.

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa[(wa['Year'] == 1986) & (wa['WHO region'] == 'Western Pacific') & (wa['Country'] == 'Viet Nam')]
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0

# %% [markdown]
# Thoughts: remember that for 'and' statements, I need to use the symbol and not the word for these filter methods

# %% [markdown]
# Sample Solution 9)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details in the year 1986 where WHO region is Western Pacific and country is VietNam :")
print(w_a_con[(w_a_con['Year']==1986) & (w_a_con['WHO region']=='Western Pacific') & (w_a_con['Country']=='Viet Nam')])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details in the year 1986 where WHO region is Western Pacific and country is VietNam :
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0

# %% [markdown]
# **Problem 10)** Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' from the world alcohol consumption dataset.

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa[((wa['Year'] == 1986) | (wa['Year'] == 1989)) & (wa['WHO region'] == 'Americas')]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 47  1986   Americas                            Mexico          Other
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 74  1986   Americas  Bolivia (Plurinational State of)        Spirits
# 78  1989   Americas                           Jamaica          Other
# 86  1986   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 11           0.62
# 21           4.51
# 47           0.04
# ...

# %% [markdown]
# sample solution 10 does not exist

# %% [markdown]
# **Problem 11)** Write a Pandas program to find out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa[((wa['Year'] == 1986) | (wa['Year'] == 1989)) & ((wa['WHO region'] == 'Americas') | (wa['WHO region'] == 'Europe'))]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 29  1986     Europe                             Italy          Other
# 34  1986     Europe                Russian Federation           Wine
# 37  1986     Europe                            Sweden           Beer
# 41  1986     Europe                    Czech Republic           Beer
# 47  1986   Americas                            Mexico          Other
# 49  1986     Europe                             Malta           Wine
# 55  1989   Americas                          Suriname           Wine
# 57  1989     Europe                           Croatia           Wine
# ...

# %% [markdown]
# Sample Solution 11)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details in the year ‘1986’ or ‘1989’ where  WHO region is ‘Americas’  or 'Europe':")
print(w_a_con[((w_a_con['Year']==1985) | (w_a_con['Year']==1989)) & ((w_a_con['WHO region']=='Americas') | (w_a_con['WHO region']=='Europe'))].head(10))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details in the year ‘1986’ or ‘1989’ where  WHO region is ‘Americas’  or 'Europe':
#     Year WHO region                                            Country  \
# 11  1989   Americas                                          Guatemala
# 21  1989   Americas                                         Costa Rica
# 26  1985     Europe  United Kingdom of Great Britain and Northern I...
# ...

# %% [markdown]
# **Problem 12)** Write a Pandas program to find out the 'WHO region, 'Country', 'Beverage Types' in the year '1986' or '1989' where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa[((wa['Year'] == 1986) | (wa['Year'] == 1989)) & ((wa['WHO region'] == 'Americas') | (wa['WHO region'] == 'Europe'))].loc[:,['WHO region', 'Country', 'Beverage Types']]
# Out:
#    WHO region                           Country Beverage Types
# 1    Americas                           Uruguay          Other
# 3    Americas                          Colombia           Beer
# 8    Americas               Antigua and Barbuda        Spirits
# 11   Americas                         Guatemala           Beer
# 21   Americas                        Costa Rica        Spirits
# 29     Europe                             Italy          Other
# 34     Europe                Russian Federation           Wine
# 37     Europe                            Sweden           Beer
# 41     Europe                    Czech Republic           Beer
# 47   Americas                            Mexico          Other
# 49     Europe                             Malta           Wine
# 55   Americas                          Suriname           Wine
# 57     Europe                           Croatia           Wine
# 64   Americas  Bolivia (Plurinational State of)           Beer
# ...

# %% [markdown]
# Sample Solution 12)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details ('WHO region','Country','Beverage Types') \nin the year ‘1986’ or ‘1989’ where  WHO region is ‘Americas’  or 'Europe':")
w_a_con[((w_a_con['Year']==1985) | (w_a_con['Year']==1989)) & ((w_a_con['WHO region']=='Americas') | (w_a_con['WHO region']=='Europe'))][['WHO region','Country','Beverage Types']].head(10)
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details ('WHO region','Country','Beverage Types')
# in the year ‘1986’ or ‘1989’ where  WHO region is ‘Americas’  or 'Europe':
#    WHO region                                            Country  \
# 11   Americas                                          Guatemala
# 21   Americas                                         Costa Rica
# 26     Europe  United Kingdom of Great Britain and Northern I...
# ...

# %% [markdown]
# Thoughts: The sample solution method of using double brackets to constain the columns keeps the index of the original dataframe for each row whereas the method of using .loc[] will result in a new integer index

# %% [markdown]
# **Problem 13)** Write a Pandas program to find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset.

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa[(wa['Display Value'] >= 5) & (wa['Beverage Types'] == 'Beer')]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# Sample Solution 13)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details: average consumption of \nbeverages per person >=5 and Beverage Types is Beer:")
print(w_a_con[(w_a_con['Display Value'] >= 5) & (w_a_con['Beverage Types'] == 'Beer')].head(10))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details: average consumption of
# beverages per person >=5 and Beverage Types is Beer:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# **Problem 14)** Write a Pandas program to find out the records where consumption of beverages per person average >=4 and Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset.

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
wa[(wa['Display Value'] >= 4) & (wa['Beverage Types'].isin(['Beer', 'Wine', 'Spirits']))]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 3   1986   Americas        Colombia           Beer           4.27
# 21  1989   Americas      Costa Rica        Spirits           4.51
# 41  1986     Europe  Czech Republic           Beer           6.82
# 57  1989     Europe         Croatia           Wine           5.10
# 91  1989     Europe        Bulgaria           Beer           4.43
# 96  1985     Europe      Luxembourg           Wine           7.38

# %% [markdown]
# Sample Solution 14)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nThe world alcohol consumption details: average consumption of \nbeverages per person >=4 and Beverage Types is Beer:")
w_a_con[(w_a_con['Display Value'] >= 4) & ((w_a_con['Beverage Types'] == 'Beer') | (w_a_con['Beverage Types'] == 'Wine')| (w_a_con['Beverage Types'] == 'Spirits'))]
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# The world alcohol consumption details: average consumption of
# beverages per person >=4 and Beverage Types is Beer:
#     Year WHO region         Country Beverage Types  Display Value
# 3   1986   Americas        Colombia           Beer           4.27
# 21  1989   Americas      Costa Rica        Spirits           4.51
# 41  1986     Europe  Czech Republic           Beer           6.82
# 57  1989     Europe         Croatia           Wine           5.10
# ...

# %% [markdown]
# **Problem 15)** Write a Pandas program to filter the specified columns and records by range from world alcohol consumption dataset.

# %%
wa.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
print(wa['Year'].min())
print(wa['Year'].max())
# Out:
# 1984
# 1989

# %%
wa_year_sorted = wa.sort_values(by='Year', ascending = True)
wa_year_sorted
# Out:
#     Year             WHO region                           Country  \
# 23  1984                 Europe                            Turkey
# 43  1984        Western Pacific                             China
# 42  1984                 Europe                           Ukraine
# 53  1984  Eastern Mediterranean                            Kuwait
# 54  1984               Americas                       El Salvador
# ..   ...                    ...                               ...
# 65  1989  Eastern Mediterranean                           Somalia
# 64  1989               Americas  Bolivia (Plurinational State of)
# 57  1989                 Europe                           Croatia
# 11  1989               Americas                         Guatemala
# 79  1989                 Europe                           Finland
#
#    Beverage Types  Display Value
# 23           Beer           0.44
# 43           Wine           0.03
# 42        Spirits           3.06
# 53           Beer           0.00
# ...

# %% [markdown]
# Sample Solution 15)

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFiltering records by label or index:")
print(w_a_con.loc[0:4, ["WHO region", "Beverage Types"]])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Filtering records by label or index:
#         WHO region Beverage Types
# 0  Western Pacific           Wine
# 1         Americas          Other
# 2           Africa           Wine
# 3         Americas           Beer
# 4         Americas           Beer

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Problem 16) Write a Pandas program to filter those records where WHO region contains "Ea" substring from world alcohol consumption dataset

# %%
#looking at data
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
df = world_alcohol[world_alcohol['WHO region']
# Out:
# Empty DataFrame
# Columns: [Year, WHO region, Country, Beverage Types, Display Value]
# Index: []

# %% [markdown]
# Thoughts: This is a tough one, dealing with strings is something I do not have much experience with, I tried using .contains() and .isin() but those did not work, will look at sample solution

# %% [markdown]
# **Sample Solution 16)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
# Remove NA / NaN values
new_w_a_con = w_a_con.dropna()
print("\nMatch if  a given column has a particular sub string:")
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Match if  a given column has a particular sub string:

# %%
new_w_a_con[new_w_a_con["WHO region"].str.contains("Ea")].head()
# Out:
#     Year             WHO region      Country Beverage Types  Display Value
# 13  1984  Eastern Mediterranean  Afghanistan          Other           0.00
# 20  1986        South-East Asia      Myanmar           Wine           0.00
# 25  1984  Eastern Mediterranean      Tunisia          Other           0.00
# 27  1984  Eastern Mediterranean      Bahrain           Beer           2.22
# 36  1987  Eastern Mediterranean        Egypt           Beer           0.07

# %% [markdown]
# Thoughts: so I had the right idea with using .contains() the issue was that I had to explicitly change the type of the WHO region column to str as contains() is an attribute of str. Very interesting

# %%
#so just redoing the sample solution to further solidify what I have learned
df = world_alcohol[world_alcohol['WHO region'].str.contains('Ea')]
df.head()
# Out:
#     Year             WHO region      Country Beverage Types  Display Value
# 13  1984  Eastern Mediterranean  Afghanistan          Other           0.00
# 20  1986        South-East Asia      Myanmar           Wine           0.00
# 25  1984  Eastern Mediterranean      Tunisia          Other           0.00
# 27  1984  Eastern Mediterranean      Bahrain           Beer           2.22
# 36  1987  Eastern Mediterranean        Egypt           Beer           0.07

# %% [markdown]
# **Problem 17)** Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption

# %%
#looking at data
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol[world_alcohol['WHO region'].isin(['Africa', 'Eastern Mediterranean', 'Europe'])].head()
# Out:
#     Year WHO region       Country Beverage Types  Display Value
# 2   1985     Africa  Cte d'Ivoire           Wine           1.62
# 6   1987     Africa     Mauritius           Wine           0.13
# 7   1985     Africa        Angola        Spirits           0.39
# 9   1984     Africa       Nigeria          Other           6.10
# 10  1987     Africa      Botswana           Wine           0.20

# %% [markdown]
# **Sample Solution 17)**

# %%
import pandas as pd
# World alcohol consumption data
new_w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(new_w_a_con.head())
print("\nFilter by matching multiple values in a given dataframe:")
flt_wine = new_w_a_con["WHO region"].isin(["Africa", "Eastern Mediterranean", "Europe"])
print(new_w_a_con[flt_wine])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Filter by matching multiple values in a given dataframe:
#     Year WHO region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# ...

# %% [markdown]
# **Problem 18)** Write a Pandas program to filter those records which not appears in a given list from world alcohol consumption dataset.

# %%
#so I think the problem wants me to create a list and then filter the WA dataset for items that are NOT in the list
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
given_list = ['Wine', 'Spirits']
print('Shape of dataset that IS IN the given list')
print(world_alcohol[world_alcohol['Beverage Types'].isin(given_list)].shape)
# Out:
# Shape of dataset that IS IN the given list
# (48, 5)

# %%
print('Shape of dataset that IS NOT in the given list')
print(world_alcohol[~world_alcohol['Beverage Types'].isin(given_list)].shape)
# Out:
# Shape of dataset that IS NOT in the given list
# (52, 5)

# %% [markdown]
# Thoughts: so for doing NOT IN or OPPOSITE OF, using the "~" is great and for this question, I am finding the dataset that does not appear in the given list. will be interesting to see if the sample solution does the same thing, they will probably introduce a new method, lets find out..

# %% [markdown]
# **Sample Solution 18)**

# %%
import pandas as pd
# World alcohol consumption data
new_w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(new_w_a_con.head())
print("\nSelect all rows which not appears in a given list:")
who_region = ["Africa", "Eastern Mediterranean", "Europe"]
flt_wine = ~new_w_a_con["WHO region"].isin(who_region)
print(new_w_a_con[flt_wine])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Select all rows which not appears in a given list:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# ...

# %% [markdown]
# Thoughts: So they did use the squiggly "~"  that's gnar

# %% [markdown]
# **Problem 19)** Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset.

# %%
#looking at data
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol[(world_alcohol['Display Value'] >= .50) & (world_alcohol['Display Value'] <= 2.5)].head()
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 1   1986   Americas                Uruguay          Other           0.50
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 8   1986   Americas    Antigua and Barbuda        Spirits           1.55
# 11  1989   Americas              Guatemala           Beer           0.62

# %% [markdown]
# **Sample Solution 19)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFilter all records where the average consumption of beverages per person from .5 to 2.50.:")
print(w_a_con[(w_a_con['Display Value'] < 2.5) & (w_a_con['Display Value']>.5)].head())
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Filter all records where the average consumption of beverages per person from .5 to 2.50.:
#     Year WHO region                Country Beverage Types  Display Value
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 8   1986   Americas    Antigua and Barbuda        Spirits           1.55
# 11  1989   Americas              Guatemala           Beer           0.62
# ...

# %% [markdown]
# **Problem 20)** Write a Pandas program to find average consumption of wine per person greater than 2 in world alcohol consumption dataset

# %%
#looking at data
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
df = world_alcohol[(world_alcohol['Beverage Types'] == 'Wine') & (world_alcohol['Display Value'] > 2.0)]
df['Display Value'].mean()
# Out:
# 5.006666666666667

# %%
df.agg({'Display Value': 'mean'})
# Out:
# Display Value    5.006667
# dtype: float64

# %% [markdown]
# **Sample Solution 20)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nAverage consumption of wine per person greater than 2:")
print(w_a_con[(w_a_con['Beverage Types'] == 'Wine') & (w_a_con['Display Value'] > .2)].count())
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Average consumption of wine per person greater than 2:
# Year              9
# WHO region        9
# Country           9
# Beverage Types    9
# Display Value     9
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Problem 21) Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset.

# %%
#looking at data
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol[world_alcohol.index.isin([np.arange(0,100,10)])]
world_alcohol.index.max()
# Out:
# 99

# %%
#so index goes to 99, can use np.arange in 10 integer intervals
world_alcohol[pd.Series(world_alcohol.index.values).isin(np.arange(0,100,10))]
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %% [markdown]
# Thoughts: so df.index has an attribute of .values that give a numpy array of the index values. BUT .isin() is an attribute of pandas Series, so I wrapped up  the index values in pd.Series so I could use the .isin() attribute.
# This is something that I am noticing much more with coding in Python, attributes that I may want to use can only be used on certain datatypes, so If I want to use a particular attribute, I must figure out what datatype it can be used for, then transform the data to that dtype in order to use the wanted attribute.
# Wonder if the sample solution will have something more simple.

# %% [markdown]
# **Sample Solution 21)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFilter rows based on row numbers ended with 0, like 0, 10, 20, 30:")
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Filter rows based on row numbers ended with 0, like 0, 10, 20, 30:

# %%
w_a_con.filter(regex='0$', axis=0)
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %% [markdown]
# Thoughts: very intersting, the sample solution brings in a function of filter and used a regular expression on the index axis.

# %% [markdown]
# **Problem 22** Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption dataset

# %%
#looking at dataset
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol.iloc[0:10, 0:3]
# Out:
#    Year       WHO region                Country
# 0  1986  Western Pacific               Viet Nam
# 1  1986         Americas                Uruguay
# 2  1985           Africa           Cte d'Ivoire
# 3  1986         Americas               Colombia
# 4  1987         Americas  Saint Kitts and Nevis
# 5  1987         Americas              Guatemala
# 6  1987           Africa              Mauritius
# 7  1985           Africa                 Angola
# 8  1986         Americas    Antigua and Barbuda
# 9  1984           Africa                Nigeria

# %% [markdown]
# **Sample Solution 22)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nSelect consecutive columns:")
print(w_a_con.loc[:,"Country":"Display Value"].head())
print("\nAlternate command:")
print(w_a_con.iloc[:,2:5].head())
print("\nSelect rows with Index label 0 to 9 with specific columns:")
print(w_a_con.loc[0:9,["Year","Country","Display Value"]])
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Select consecutive columns:
#                  Country Beverage Types  Display Value
# 0               Viet Nam           Wine           0.00
# 1                Uruguay          Other           0.50
# 2           Cte d'Ivoire           Wine           1.62
# 3               Colombia           Beer           4.27
# 4  Saint Kitts and Nevis           Beer           1.98
#
# Alternate command:
#                  Country Beverage Types  Display Value
# ...

# %% [markdown]
# **Problem 23)** Write a Pandas program to rename all and only some of the column names from world alcohol consumption dataset

# %%
#looking at dataset
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
#renaming all columns and some columns is the same syntax, so will only rename 2 columns
df = world_alcohol.rename(columns={'WHO region' : 'Region', 'Beverage Types' : 'Drink Types'})
df.head()
# Out:
#    Year           Region                Country Drink Types  Display Value
# 0  1986  Western Pacific               Viet Nam        Wine           0.00
# 1  1986         Americas                Uruguay       Other           0.50
# 2  1985           Africa           Cte d'Ivoire        Wine           1.62
# 3  1986         Americas               Colombia        Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis        Beer           1.98

# %% [markdown]
# **Sample Solution 23)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
new_w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nRename all the column names:")
w_a_con.columns = ['year','who_region','country','beverage_types','display_values']
print(w_a_con.head())
print("\nRenaming only some of the column names:")
new_w_a_con.rename(columns = {"WHO region":"WHO_region","Display Value":"Display_Value" },inplace = True)
print(new_w_a_con.head())
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Rename all the column names:
#    year       who_region                country beverage_types  display_values
# 0  1986  Western Pacific               Viet Nam           Wine            0.00
# 1  1986         Americas                Uruguay          Other            0.50
# 2  1985           Africa           Cte d'Ivoire           Wine            1.62
# 3  1986         Americas               Colombia           Beer            4.27
# ...

# %% [markdown]
# **Problem 24)** Write a Pandas program to find which years have all non-zero values and which years have any non-zero values from world alcohol consumption dataset

# %%
#looking at dataset
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol[world_alcohol['Display Value'] == 0.00]
# Out:
#     Year             WHO region                                Country  \
# 0   1986        Western Pacific                               Viet Nam
# 5   1987               Americas                              Guatemala
# 12  1985        Western Pacific       Lao People's Democratic Republic
# 13  1984  Eastern Mediterranean                            Afghanistan
# 20  1986        South-East Asia                                Myanmar
# 25  1984  Eastern Mediterranean                                Tunisia
# 31  1986        Western Pacific       Micronesia (Federated States of)
# 33  1985                 Africa                             Mauritania
# 38  1987  Eastern Mediterranean                                  Qatar
# 52  1986  Eastern Mediterranean                           Saudi Arabia
# 53  1984  Eastern Mediterranean                                 Kuwait
# 56  1987        Western Pacific                               Viet Nam
# ...

# %% [markdown]
# **Sample Solution 24)**

# %%
import pandas as pd 

# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFind which years have all non-zero values:")
w_a_con.loc[:,w_a_con.all()]
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Find which years have all non-zero values:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ...

# %%
print("\nFind which years have any non-zero values:")
w_a_con.loc[:,w_a_con.any()]
# Out:
# Find which years have any non-zero values:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# ...

# %% [markdown]
# **Problem 25)** Write a Pandas program to filter all columns where all entries present, check which rows and columns has a NaN and finally drop rows with any NaNs from world alcohol consumption dataset

# %%
#loading dataset
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
#all entries present
df1 = world_alcohol.dropna(how = 'all')
df1.shape
# Out:
# (100, 5)

# %%
df2 = df1.dropna()
df2.shape
# Out:
# (95, 5)

# %% [markdown]
# **Sample Solution 25)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFind  all columns which all entries present:")
print(w_a_con.loc[:, w_a_con.notnull().all()])
print("\nRows and columns has a NaN:")
print(w_a_con.loc[:,w_a_con.isnull().any()])
print("\nDrop rows with any NaNs:")
print(w_a_con.dropna(how='any'))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Find  all columns which all entries present:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Problem 26) Write a Pandas program to filter all records starting from the 'Year' column, access every other column from world alcohol consumption dataset.

# %%
#looking at dataset
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
world_alcohol.iloc[:,np.arange(0,len(world_alcohol.columns),2)]
# Out:
#     Year                                Country  Display Value
# 0   1986                               Viet Nam           0.00
# 1   1986                                Uruguay           0.50
# 2   1985                           Cte d'Ivoire           1.62
# 3   1986                               Colombia           4.27
# 4   1987                  Saint Kitts and Nevis           1.98
# ..   ...                                    ...            ...
# 95  1984                                  Niger           0.00
# 96  1985                             Luxembourg           7.38
# 97  1984                              Indonesia           0.00
# 98  1984                      Equatorial Guinea           0.00
# 99  1985  Democratic People's Republic of Korea           0.00
#
# [100 rows x 3 columns]

# %% [markdown]
# **Sample Solution 26)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nFrom the 'Year' column, access every other column:")
print(w_a_con.loc[:,'Year'::2].head(10))
print("\nAlternate solution:")
print(w_a_con.iloc[:,0::2].head(10))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# From the 'Year' column, access every other column:
#    Year                Country  Display Value
# 0  1986               Viet Nam           0.00
# 1  1986                Uruguay           0.50
# 2  1985           Cte d'Ivoire           1.62
# 3  1986               Colombia           4.27
# 4  1987  Saint Kitts and Nevis           1.98
# 5  1987              Guatemala           0.00
# 6  1987              Mauritius           0.13
# ...

# %% [markdown]
# **Problem 27)** Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
#loading dataset
world_alcohol.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
#method 1
world_alcohol.iloc[2::5,:].head()
# Out:
#     Year       WHO region                           Country Beverage Types  \
# 2   1985           Africa                      Cte d'Ivoire           Wine
# 7   1985           Africa                            Angola        Spirits
# 12  1985  Western Pacific  Lao People's Democratic Republic           Beer
# 17  1989           Africa                        Seychelles           Beer
# 22  1984           Europe                           Romania        Spirits
#
#     Display Value
# 2            1.62
# 7            0.39
# 12           0.00
# 17           2.23
# 22           2.67

# %%
#method 2
world_alcohol.iloc[np.arange(2,len(world_alcohol.index),5)].head()
# Out:
#     Year       WHO region                           Country Beverage Types  \
# 2   1985           Africa                      Cte d'Ivoire           Wine
# 7   1985           Africa                            Angola        Spirits
# 12  1985  Western Pacific  Lao People's Democratic Republic           Beer
# 17  1989           Africa                        Seychelles           Beer
# 22  1984           Europe                           Romania        Spirits
#
#     Display Value
# 2            1.62
# 7            0.39
# 12           0.00
# 17           2.23
# 22           2.67

# %% [markdown]
# **Sample Solution 27)**

# %%
import pandas as pd
# World alcohol consumption data
w_a_con = pd.read_csv('world_alcohol.csv')
print("World alcohol consumption sample data:")
print(w_a_con.head())
print("\nStarting from the 2nd row, access every 5th row:")
print(w_a_con.iloc[1::5].head(10))
# Out:
# World alcohol consumption sample data:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
#
# Starting from the 2nd row, access every 5th row:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
#
# ...
